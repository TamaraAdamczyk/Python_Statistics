# %% [markdown]
# <a href="https://colab.research.google.com/github/TamaraAdamczyk/Python_Statistics/blob/main/meanandmedian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics
statistics.mean([4, 5, 20, 22, 22, 24, 24, 26, 27, 29, 29])
# Out:
# 21.09090909090909

# %%
statistics.median([4, 5, 20, 22, 22, 24, 24, 26, 27, 29, 29])
# Out:
# 24

# %%
statistics.mean([7, 3, 5, 12, 6, 7, 25, 9, 23, 9, 12, 3, 12, 23])
# Out:
# 11.142857142857142

# %%
statistics.median([7, 3, 5, 12, 6, 7, 25, 9, 23, 9, 12, 3, 12, 23])
# Out:
# 9.0
